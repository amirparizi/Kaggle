# %%
# NumPy
import numpy as np

# Dataframe operations
import pandas as pd

# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge

# Scalers
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

# Models
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn.linear_model import Perceptron
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier

# Cross-validation
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
from sklearn.model_selection import cross_validate

# GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# %%
conda install -c anaconda py-xgboost
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
train= pd.read_csv('train_.csv')
train['LotFrontage'].replace(np.nan, 0, regex=True,inplace=True)
train['Alley'].replace(np.nan, 'NA', regex=True,inplace=True)
train['MasVnrType'].replace(np.nan, 'None', regex=True,inplace=True)
train['MasVnrArea'].replace(np.nan, 0, regex=True,inplace=True)
train['BsmtQual'].replace(np.nan, 'None', regex=True,inplace=True)
train['BsmtCond'].replace(np.nan, 'None', regex=True,inplace=True)
train['BsmtExposure'].replace(np.nan, 'None', regex=True,inplace=True)
train['BsmtFinType1'].replace(np.nan, 'None', regex=True,inplace=True)
train['BsmtFinType2'].replace(np.nan, 'None', regex=True,inplace=True)
train['Electrical'].replace(np.nan, 'SBrkr', regex=True,inplace=True)
train['FireplaceQu'].replace(np.nan, 'None', regex=True,inplace=True)
train['GarageType'].replace(np.nan, 'None', regex=True,inplace=True)
train['GarageFinish'].replace(np.nan, 'None', regex=True,inplace=True)
train['GarageYrBlt'].replace(np.nan, 0, regex=True,inplace=True)
train['GarageQual'].replace(np.nan, 'None', regex=True,inplace=True)
train['GarageCond'].replace(np.nan, 'None', regex=True,inplace=True)
train['PoolQC'].replace(np.nan, 'None', regex=True,inplace=True)
train['Fence'].replace(np.nan, 'None', regex=True,inplace=True)
train['MiscFeature'].replace(np.nan, 'None', regex=True,inplace=True)
print(train.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave    NA      Reg
# 1   2          20       RL         80.0     9600   Pave    NA      Reg
# 2   3          60       RL         68.0    11250   Pave    NA      IR1
# 3   4          70       RL         60.0     9550   Pave    NA      IR1
# 4   5          60       RL         84.0    14260   Pave    NA      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0   None  None        None       0      2
# 1         Lvl    AllPub  ...        0   None  None        None       0      5
# 2         Lvl    AllPub  ...        0   None  None        None       0      9
# 3         Lvl    AllPub  ...        0   None  None        None       0      2
# 4         Lvl    AllPub  ...        0   None  None        None       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
x=train.dtypes =='object'

# %%
obj=x[x==True]

# %%
train=train.join(pd.get_dummies(train[obj.index]))

# %%
num_train=train.drop(train[obj.index],axis=1)

# %%
num_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# ...

# %%
label = LabelEncoder()
num_train['YearBuilt_code'] = label.fit_transform(num_train['YearBuilt'])
num_train['YearBuilt_code'] = num_train['YearBuilt_code'][:1460]
num_train['YearRemodAdd_code'] = label.fit_transform(num_train['YearRemodAdd'])
num_train['YearRemodAdd_code'] = num_train['YearRemodAdd_code'][:1460]
num_train['YrSold_code'] = label.fit_transform(num_train['YrSold'])
num_train['YrSold_code'] = num_train['YrSold_code'][:1460]
num_train['MoSold_code'] = label.fit_transform(num_train['MoSold'])
num_train['MoSold_code'] = num_train['MoSold_code'][:1460]
num_train=num_train.drop(num_train[['YearBuilt','YearRemodAdd','YrSold','MoSold']],axis=1)

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
num_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  \
# ...

# %%
Y_train=num_train['SalePrice']
X_train=num_train.drop(num_train[['Id','SalePrice']],axis=1)

# %%
Y_train
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  \
# 0             60         65.0     8450            7            5       196.0
# 1             20         80.0     9600            6            8         0.0
# 2             60         68.0    11250            7            5       162.0
# 3             70         60.0     9550            7            5         0.0
# 4             60         84.0    14260            8            5       350.0
# ...          ...          ...      ...          ...          ...         ...
# 1455          60         62.0     7917            6            5         0.0
# 1456          20         85.0    13175            6            6       119.0
# 1457          70         66.0     9042            7            9         0.0
# 1458          20         68.0     9717            5            6         0.0
# 1459          20         75.0     9937            5            6         0.0
#
# ...

# %%
test= pd.read_csv('test_.csv')

# %%
test['LotFrontage'].replace(np.nan, 0, regex=True,inplace=True)
test['Alley'].replace(np.nan, 'NA', regex=True,inplace=True)
test['MasVnrType'].replace(np.nan, 'None', regex=True,inplace=True)
test['MasVnrArea'].replace(np.nan, 0, regex=True,inplace=True)
test['BsmtQual'].replace(np.nan, 'None', regex=True,inplace=True)
test['BsmtCond'].replace(np.nan, 'None', regex=True,inplace=True)
test['BsmtExposure'].replace(np.nan, 'None', regex=True,inplace=True)
test['BsmtFinType1'].replace(np.nan, 'None', regex=True,inplace=True)
test['BsmtFinType2'].replace(np.nan, 'None', regex=True,inplace=True)
test['Electrical'].replace(np.nan, 'SBrkr', regex=True,inplace=True)
test['FireplaceQu'].replace(np.nan, 'None', regex=True,inplace=True)
test['GarageType'].replace(np.nan, 'None', regex=True,inplace=True)
test['GarageFinish'].replace(np.nan, 'None', regex=True,inplace=True)
test['GarageYrBlt'].replace(np.nan, 0, regex=True,inplace=True)
test['GarageQual'].replace(np.nan, 'None', regex=True,inplace=True)
test['GarageCond'].replace(np.nan, 'None', regex=True,inplace=True)
test['PoolQC'].replace(np.nan, 'None', regex=True,inplace=True)
test['Fence'].replace(np.nan, 'None', regex=True,inplace=True)
test['MiscFeature'].replace(np.nan, 'None', regex=True,inplace=True)
test['MSZoning'].replace(np.nan, 'None', regex=True,inplace=True)
test['Utilities'].replace(np.nan, 'None', regex=True,inplace=True)
test['Exterior1st'].replace(np.nan, 'None', regex=True,inplace=True)
test['Exterior2nd'].replace(np.nan, 'None', regex=True,inplace=True)
test['BsmtFinSF1'].replace(np.nan, 0, regex=True,inplace=True)
test['BsmtFinSF2'].replace(np.nan, 0, regex=True,inplace=True)
test['BsmtUnfSF'].replace(np.nan, 0, regex=True,inplace=True)
test['TotalBsmtSF'].replace(np.nan, 0, regex=True,inplace=True)
test['BsmtFullBath'].replace(np.nan, 0, regex=True,inplace=True)
test['BsmtHalfBath'].replace(np.nan, 0, regex=True,inplace=True)
test['KitchenQual'].replace(np.nan, 'None', regex=True,inplace=True)
test['Functional'].replace(np.nan, 'None', regex=True,inplace=True)
test['GarageCars'].replace(np.nan, 0, regex=True,inplace=True)
test['GarageArea'].replace(np.nan, 0, regex=True,inplace=True)
test['SaleType'].replace(np.nan, 'None', regex=True,inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          1459 non-null   object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1459 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
test=test.join(pd.get_dummies(train[obj.index]))
num_test=test.drop(train[obj.index],axis=1)

# %%
label = LabelEncoder()
num_test['YearBuilt_code'] = label.fit_transform(num_test['YearBuilt'])
num_test['YearBuilt_code'] = num_test['YearBuilt_code'][:1459]
num_test['YearRemodAdd_code'] = label.fit_transform(num_test['YearRemodAdd'])
num_test['YearRemodAdd_code'] = num_test['YearRemodAdd_code'][:1459]
num_test['YrSold_code'] = label.fit_transform(num_test['YrSold'])
num_test['YrSold_code'] = num_test['YrSold_code'][:1459]
num_test['MoSold_code'] = label.fit_transform(num_test['MoSold'])
num_test['MoSold_code'] = num_test['MoSold_code'][:1459]
num_test=num_test.drop(num_test[['Id','YearBuilt','YearRemodAdd','YrSold','MoSold']],axis=1)

# %%
test['Id']
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor
import numpy as np
#Load boston housing dataset as an example
rf = RandomForestRegressor()
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
importances = pd.Series(data=rf.feature_importances_,
                        index= X_train.columns)
importances_sorted = importances.sort_values()

# %%
important_index=importances_sorted[importances_sorted > 0.001].index

# %%
important_index
# Out:
# Index(['FireplaceQu_None', 'KitchenQual_Ex', 'BsmtFullBath', 'ScreenPorch',
#        'BsmtExposure_Gd', 'ExterQual_Gd', 'BedroomAbvGr', 'MSSubClass',
#        'YrSold_code', 'LotShape_Reg', 'CentralAir_N', 'MSZoning_RM',
#        'GarageType_Attchd', 'CentralAir_Y', 'BsmtQual_Gd', 'GarageType_Detchd',
#        'KitchenQual_Gd', 'Fireplaces', 'MoSold_code', 'BsmtQual_Ex',
#        'WoodDeckSF', 'OverallCond', 'MasVnrArea', 'BsmtUnfSF', 'OpenPorchSF',
#        'GarageYrBlt', 'TotRmsAbvGrd', 'LotFrontage', 'FullBath',
#        'YearRemodAdd_code', 'YearBuilt_code', 'LotArea', 'GarageArea',
#        'GarageCars', '1stFlrSF', 'BsmtFinSF1', '2ndFlrSF', 'TotalBsmtSF',
#        'GrLivArea', 'OverallQual'],
#       dtype='object')

# %%
X_train=X_train[important_index]
X_test=num_test[important_index]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
from xgboost import XGBRegressor

# %%
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

XGB = XGBRegressor(n_estimators=30,learning_rate=0.67)

# Fit the model
XGB.fit(X_train,Y_train) 
y_pred=XGB.predict(X_test)
# Out:
# [16:45:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
Y_train
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
X_train
# Out:
# array([[1.        , 0.        , 0.33333333, ..., 0.1400982 , 0.25923135,
#         0.66666667],
#        [0.        , 0.        , 0.        , ..., 0.20654664, 0.17483044,
#         0.55555556],
#        [0.        , 0.        , 0.33333333, ..., 0.15057283, 0.27354936,
#         0.66666667],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.18854337, 0.37792012,
#         0.66666667],
#        [1.        , 0.        , 0.33333333, ..., 0.17643208, 0.14016579,
#         0.44444444],
#        [1.        , 0.        , 0.33333333, ..., 0.20556465, 0.17370008,
#         0.44444444]])

# %%
X_train1, X_valid1, y_train1, y_valid1 = train_test_split(X_train, Y_train, random_state=0)
XGB = XGBRegressor(n_estimators=30,learning_rate=0.67)
lr = LinearRegression()
# Fit the model
XGB.fit(X_train1,y_train1) 
lr.fit(X_train1,y_train1) 
# Get predictions
pred_XGB = XGB.predict(X_valid1)
pred_lr = lr.predict(X_valid1)
# Calculate MAE
mae_XGB =  mean_absolute_error(pred_XGB,y_valid1)
mae_lr =  mean_absolute_error(pred_lr,y_valid1)
# Uncomment to print MAE
print("Mean Absolute Error XGB:" , mae_XGB)
print("Mean Absolute Error lr:" , mae_lr)
# Out:
# [16:45:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Mean Absolute Error XGB: 21586.616042380138
# Mean Absolute Error lr: 20172.502019643292

# %%
lr.fit(X_train,Y_train)
y_pred=lr.predict(X_test)

# %%
Y_train
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
y_pred
# Out:
# array([126269.94494768, 170895.05884633, 179059.79141905, ...,
#        164122.05462781, 108714.71599387, 228265.45089627])

# %%
output = pd.DataFrame({'Id': test['Id'],
                       'SalePrice': y_pred})
output.to_csv('submission_sale_V13.csv', index=False)
